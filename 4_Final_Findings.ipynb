# %% [markdown]
# <div style="background-color:#e3f2fd; padding:20px; border-radius:15px; color:#0d47a1; font-family:'Segoe UI', sans-serif; font-size:18px; line-height:1.6;">
#
#   <span style="font-size:30px; font-weight:bold;">Final Findings</span><br>
#
#   ### 1. Appointments
#   - Total 200 appointments, but only 46 (23%) were completed.
#   - No-shows (26%) and cancellations are the main reasons for low completion.
#   - Checkups and Follow-ups have better completion rates.
#   - Therapy, Emergency, and Consultations mostly get cancelled or patients don’t come.
#   - Even in months with many bookings, completions are low:
#     - April: 24 bookings -> only 9 completed.
#     - October: 14 bookings -> none completed.
#
#   <br>
#
#   ### 2. Billing (Payments)
#   - Total bill amount: USD 551K, but only USD 173K (31%) collected.
#   - 69% of payments are still pending or failed.
#   - Failed payments are the highest (USD 193K).
#   - Money collected came almost equally from Insurance, Credit Card, and Cash (~USD 60K each).
#   - June was the best month (USD 30K+ collected).
#   - February and July were the weakest months (less than USD 8K collected).
#   - Even after completion, only 14 appointments had successful payment.
#   - Weak billing follow-up: Many scheduled appointments end with Failed/Pending payments.
#   - Resource wastage: Cancelled & No-show appointments still appear with billing records.
#   - Even Completed appointments often show Failed/Pending payment.
#   - Paid status is scattered (ECG, MRI, Physiotherapy, Chemotherapy) but rare compared to Failed/Pending.
#
#   <br>
#
#   ### 3. Doctors & Branches
#   - Total 10 doctors: Pediatrics (5), Dermatology (3), Oncology (2).
#   - Most doctors are experienced (17–28 years). Only one junior (5 years).
#   - Top doctor: Dr. Linda Wilson (Oncology) – USD 8,524 revenue, 4 completions.
#   - Lowest: Dr. Linda Brown (Dermatology, 5 years) – only USD 1,286.
#   - Branch performance:
#     - Eastside: Best – 7 completions, USD 14,470 earned.
#     - Central: 4 completions, USD 9,544 earned.
#     - Westside: Weakest – 3 completions, USD 7,048 earned.
#
#   <br>
#
#   ### 4. Patients
#   - Total patients: 50 (31 Male, 19 Female).
#   - Age range: 20–75 years.
#   - Highest new registrations: Sept 2021 (5), Sept 2022 (4), June 2023 (4).
#   - Insurance coverage:
#     - MedCare Plus: 18 patients – most common but low spending.
#     - WellnessCorp: 16 patients – high spending.
#     - PulseSecure: 10 patients – fewer but high spend per visit.
#     - HealthIndia: 6 patients – lowest revenue.
#   - Spending pattern: Males in 30s spend most, Females 50+ spend least.
#   - Top spenders: Emily Miller (USD 4,289), Robert Miller (USD 4,186), Michael.
#   - Lowest spender: Jane Jones (USD 1,472).
#   - Patient-specific insight: Patient P005 has highly inconsistent history (Scheduled, Completed, No-shows with mixed payments).
#
#   <br>
#
#   ### 5. Treatments
#   - Total 200 treatments in 2023.
#   - Most common: Chemotherapy (49) and X-Ray (41).
#   - Least common: MRI (36) and Physiotherapy (36).
#   - By revenue:
#     - Chemotherapy highest – USD 19,995.
#     - X-Ray second – ~USD 36,700 (combined).
#     - ECG (Advanced) – USD 14,327.
#   - By month: April highest (25 treatments), Sept lowest (11).
#
#   <br>
#
#   ### 6. Revenue Trends
#   - By specialization: Pediatrics highest (USD 12,953), Oncology high per doctor, Dermatology lowest.
#   - By day: Sunday earns most, Friday least.
#   - By time: Peak at 10 AM & 2 PM. Drop at 1 PM and after 3 PM.
#   - By month: September & June strongest, December weakest.
#   - By appointment:
#     - Highest single revenue: USD 4,289 (March, Thursday 2 PM).
#     - Lowest: USD 804 (March, Friday).
#
#   <br>
#
#   ### Final Conclusion
#   - Appointment completion is very low (23%) -> Big revenue loss.
#   - Billing system is weak – Only 31% collected, many failed payments.
#   - Experienced doctors earn much more – juniors struggle.
#   - Eastside branch best, Westside weakest.
#   - Young male patients (30s) with WellnessCorp spend the most.
#   - Few top patients drive most revenue.
#   - Chemotherapy & X-Ray are main revenue drivers.
#   - Best revenue days: Sunday & Thursday. Best hours: 10 AM & 2 PM.
#   - September & June are strong months, December very weak.
#
# </div>
